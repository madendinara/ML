# %%
import sys
import numpy
import pandas
import pylab

x1 = np.linspace(0,30,100)
f = sin(x1 / 5) * exp(x1 / 10) + 5 * exp(-x1 / 2) 
pylab.plot(x1, f)
pylab.show()

def f(x):
    return (sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)) 
res = optimize.minimize(f,2,method='BFGS')
round(res.x[0],2)
# Out:
# 4.14

# %%
def f(x):
    return  sin(x / 5) * exp(x / 10) + 5 * exp(-x / 2)
